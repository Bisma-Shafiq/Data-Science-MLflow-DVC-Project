# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
dataset = pd.read_csv('data/raw_data.csv')
dataset.head()
# Out:
#                                  car_name  Year fuel_type transmission  owner  \
# 0  Jeep Compass 2.0 Longitude Option BSIV  2017    Diesel       Manual      1
# 1            Renault Duster RXZ Turbo CVT  2021    Petrol    Automatic      1
# 2                      Toyota Camry 2.5 G  2016    Petrol    Automatic      1
# 3                       Honda Jazz VX CVT  2018    Petrol    Automatic      1
# 4        Volkswagen Polo 1.2 MPI Highline  2016    Petrol       Manual      1
#
#    Selling Price
# 0          10.03
# 1          12.83
# 2          16.40
# 3           7.77
# 4           5.15

# %% [markdown]
# ### Null Value

# %%
dataset.isnull().sum()
# Out:
# car_name         0
# Year             0
# fuel_type        0
# transmission     0
# owner            0
# Selling Price    0
# dtype: int64

# %% [markdown]
# ### Duplicate remove

# %%
dataset.duplicated().sum()
# Out:
# 629

# %%
dataset.drop_duplicates(inplace=True)

# %%
# Again check duplicate value
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Data Types

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5512 entries, 0 to 5511
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   car_name       5512 non-null   object
#  1   Year           5512 non-null   int64
#  2   fuel_type      5512 non-null   object
#  3   transmission   5512 non-null   object
#  4   owner          5512 non-null   int64
#  5   Selling Price  5512 non-null   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 258.5+ KB

# %% [markdown]
# ### Unique Value

# %%
dataset.nunique()
# Out:
# car_name         1896
# Year               26
# fuel_type           5
# transmission        2
# owner               6
# Selling Price    1285
# dtype: int64

# %% [markdown]
# ### Statistic Info

# %%
dataset.describe()
# Out:
#               Year        owner  Selling Price
# count  4883.000000  4883.000000    4883.000000
# mean   2015.238173     1.441122    1879.170385
# std       3.964767     0.719857   12031.667108
# min    1995.000000     0.000000       1.000000
# 25%    2013.000000     1.000000       3.150000
# 50%    2016.000000     1.000000       5.380000
# 75%    2018.000000     2.000000       9.500000
# max    2022.000000     5.000000   99999.000000

# %% [markdown]
# ### Exploring Data

# %%
dataset.head()
# Out:
#                                  car_name  Year fuel_type transmission  owner  \
# 0  Jeep Compass 2.0 Longitude Option BSIV  2017    Diesel       Manual      1
# 1            Renault Duster RXZ Turbo CVT  2021    Petrol    Automatic      1
# 2                      Toyota Camry 2.5 G  2016    Petrol    Automatic      1
# 3                       Honda Jazz VX CVT  2018    Petrol    Automatic      1
# 4        Volkswagen Polo 1.2 MPI Highline  2016    Petrol       Manual      1
#
#    Selling Price
# 0          10.03
# 1          12.83
# 2          16.40
# 3           7.77
# 4           5.15

# %%
print("Categories in car_name column: ", dataset['car_name'].nunique())
print("Categories in fuel_type column: ", dataset['fuel_type'].nunique())
print("Categories in transmission column: ", dataset['transmission'].nunique())
print("Categories in owner column: ", dataset['owner'].nunique())
print("Categories in Year column: ", dataset['Year'].nunique())
# Out:
# Categories in car_name column:  1896
# Categories in fuel_type column:  5
# Categories in transmission column:  2
# Categories in owner column:  6
# Categories in Year column:  26

# %% [markdown]
# ### Visualization

# %%
sns.countplot(dataset['fuel_type'])
plt.show()

# %%
sns.boxplot(x="fuel_type", y="Selling Price", data=dataset)
plt.title("Selling Price Distribution by Fuel Type")
plt.xlabel("Fuel Type")
plt.ylabel("Selling Price (in Lacs)")
plt.show()

# %%
sns.countplot(x="transmission", data=dataset)
plt.title("Count of Cars by Transmission Type")
plt.xlabel("Transmission Type")
plt.ylabel("Number of Cars")
plt.show()

# %%
sns.barplot(x="owner", y="Selling Price", data=dataset, ci=None)
plt.title("Selling Price by Owner Type")
plt.xlabel("Owner (Count)")
plt.ylabel("Selling Price (in Lacs)")
plt.show()

# %%
sns.barplot(x="fuel_type", y="Selling Price", hue="transmission", data=dataset, ci=None)
plt.title("Selling Price by Fuel Type and Transmission")
plt.xlabel("Fuel Type")
plt.ylabel("Selling Price (in Lacs)")
plt.show()

# %%
dataset["Selling Price"].plot(kind="hist", bins=10, alpha=0.7, color="blue", edgecolor="black")
plt.title("Distribution of Selling Prices")
plt.xlabel("Selling Price (in Lacs)")
plt.ylabel("Frequency")
plt.show()

# %%
sns.scatterplot(x="Year", y="Selling Price", data=dataset)
plt.title("Year vs. Selling Price")
plt.xlabel("Year")
plt.ylabel("Selling Price (in Lacs)")
plt.show()
